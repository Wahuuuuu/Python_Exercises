# %% [markdown]
# # 📘 CityAI – Cerca de textos amb Expressions Regulars (RegEx)
#
# Aquesta sèrie de llibretes utilitza dades obertes de l’Ajuntament de Barcelona per practicar conceptes d’algorísmica. En aquest llibreta en concret es treballaran els patrons de text expressats mitjançant expressions regulars per tal de fer cerques dins de cadenes de text més llargues.

# %% [markdown]
# ## 🧠 Objectius
#
# Familiaritzar-se amb l'ús de les expressions regulars dins del context de Python, i veure la seva aplicació a casos reals.

# %% [markdown]
# ## ✍️ Exercici 1: Validar les adreces de correu entrades pels ciutadans
#
# L'Ajuntament de Barcelona té un formulari de suggeriments i queixes per als ciutadans i necessita assegurar-se que les adreces de correu que s'hi han introduït són vàlides per tal de poder respondre'ls i resoldre la incidència.
#
# Crea una funció que comprovi si l'adreça introduïda:
# - Té un símbol @
# - La part abans de @ no comença ni acaba amb . o -
# - La part després de @ acaba en .com, .net, o .org
# - També considerem que darrere de l'arroba hi ha d'haver un caràcter alfabètic, per exemple $...@e.com$
# - Considerem que la mínima adreça vàlida pot ser de la forma $b@e.com$, que són 7 caràcters. És a dir, un caràcter vàlid davant de l'arroba, un vàlid després i .com, .net o .org
#
# Si ho fa, digues 'Correcte'. Si no, digues 'Incorrecte'.
#
# Fes dues versions d'aquesta funció. Una primera que faci aquestes comprovacions sense utilitzar expressions regulars i una segona funció que utilitzi expressions regulars.
#
# Exemples:
#
# - $ \text{"test@example.com"} \rightarrow \text{"Correcte"}$
# - $ \text{"test@example.c"}  \rightarrow \text{"Incorrecte"}$
# - $ \text{"-test@example.com"} \rightarrow \text{"Incorrecte"}$
# - $ \text{"test@.com"} \rightarrow \text{"Incorrecte"}$
# - $ \text{"test@example.net"} \rightarrow \text{"Correcte"}$
# - $ \text{"test.@example.com"} \rightarrow \text{"Incorrecte"}$

# %%
import re
from typing import Final

# %%
def validar_adreca_manual(adreca: str) -> str:
    """
    Funció que comprova si una adreça de correu electrònic és vàlida. 
    Per ser-ho, 
    - Té un símbol @
    - La part abans de @ no comença ni acaba amb . o -
    - La part després de @ acaba en .com, .net, o .org
    - També considerem que darrere de l'arroba hi ha d'haver un caràcter alfabètic, per exemple $...@e.com$
    - Considerem que la mínima adreça vàlida pot ser de la forma $b@e.com$, que són 7 caràcters. És a dir, un caràcter vàlid davant de l'arroba, un vàlid després i .com, .net o .org

    Paràmetres:
    -----------
    adreca : str
        L'adreça de correu electrònic a comprovar

    Retorna:
    --------
    str
        Missatge que indica si l'adreça és correcte o incorrecte
    """
    if (len(adreca) < 7): return "Incorrecte"
    if (adreca.count("@") != 1): return "Incorrecte"
    
    index_at: int = adreca.find("@")
    local: str = adreca[:index_at]
    domain: str = adreca[index_at + 1:]

    BAD_CHARS: Final[set["str"]] = {".", "-"}
    if local[0] in BAD_CHARS or local[-1] in BAD_CHARS: return "Incorrecte"

    if not domain[0].isalpha(): return "Incorrecte"
    if domain[-4:] not in {".com", ".org", ".net"}: return "Incorrecte"

    return "Correcte"

# %%
def validar_adreca_regex(adreca):
    """
    Funció que comprova si una adreça de correu electrònic és vàlida. 
    Per ser-ho, 
    - Té un símbol @
    - La part abans de @ no comença ni acaba amb . o -
    - La part després de @ acaba en .com, .net, o .org
    - També considerem que darrere de l'arroba hi ha d'haver un caràcter alfabètic, per exemple $...@e.com$
    - Considerem que la mínima adreça vàlida pot ser de la forma $b@e.com$, que són 7 caràcters. És a dir, un caràcter vàlid davant de l'arroba, un vàlid després i .com, .net o .org

    Paràmetres:
    -----------
    adreca : str
        L'adreça de correu electrònic a comprovar

    Retorna:
    --------
    str
        Missatge que indica si l'adreça és correcte o incorrecte
    """
    if len(re.findall(r"@", adreca)) != 1: return "Incorrecte"
    
    m: Match = re.search(r"@", adreca)
    index_at: int = m.start()
    local: str = adreca[:index_at]  
    domain: str = adreca[index_at + 1:]

    if re.match(r"^(?![.-]).+(?<![.-])$", local) is None: return "Incorrecte"
    if re.match(r"^[a-zA-Z].*\.(com|net|org)$", domain) is None: return "Incorrecte"

    return "Correcte"

# %%
assert(validar_adreca_manual("test@example.com") == "Correcte")
assert(validar_adreca_manual("test@example.c") == "Incorrecte")
assert(validar_adreca_manual("-test@example.com") == "Incorrecte")
assert(validar_adreca_manual("test@.com") == "Incorrecte")
assert(validar_adreca_manual("test@example.net") == "Correcte")
assert(validar_adreca_manual("test.@example.com") == "Incorrecte")

# %%
assert(validar_adreca_regex("test@example.com") == "Correcte")
assert(validar_adreca_regex("test@example.c") == "Incorrecte")
assert(validar_adreca_regex("-test@example.com") == "Incorrecte")
assert(validar_adreca_regex("test@.com") == "Incorrecte")
assert(validar_adreca_regex("test@example.net") == "Correcte")
assert(validar_adreca_regex("test.@example.com") == "Incorrecte")

# %% [markdown]
# ## ✍️ Exercici 2: Identificar codis postals vàlids del Regne Unit
#
# L'Ajuntament de Barcelona s'està plantejant fer la documentació per agermanar Barcelona amb alguna ciutat del Regne Unit i ha intensificat la correspondència que manté amb aquest país. Malhauradament, com que els treballadors de l'Ajuntament no estan familiaritzats amb el format del Regne Unit, està havent més errors dels habituals.
#
# Fes una funció que comprovi si un codi postal és vàlid al Regne Unit o no utilitzant expressions regulars.
#
# Si ho és, fes que digui "# és correcte!". Si no, que digui "# no és un codi postal vàlid!"
# (on # és el codi postal que està validant).
#
# Aquí tens una llista dels diferents codis que hi havia escrits en adreces de cartes dirigides al Regne Unit i a què correponen:
#
# * "SW1A 0AA"   $ \rightarrow $   House of Commons
# * "SW1A 1AA"   $ \rightarrow $   Palau de Buckingham
# * "SW1A 2AA"   $ \rightarrow $   Downing Street
# * "BX3 2BB"   $ \rightarrow  $   Barclays Bank
# * "DH98 1BT"   $ \rightarrow $   British Telecom
# * "N1 9GU"   $ \rightarrow   $   Diari Guardian
# * "E98 1TT"   $ \rightarrow  $   The Times
# * "TIM E22"   $ \rightarrow  $   Un codi postal fals
# * "A B1 A22"   $ \rightarrow $   Un codi postal no vàlid
# * "EC2N 2DB"   $ \rightarrow $   Deutsche Bank
# * "SE9 2UG"   $ \rightarrow  $   Universitat de Greenwhich
# * "N1 0UY"   $ \rightarrow   $   Islington, Londres
# * "EC1V 8DS"   $ \rightarrow $   Clerkenwell, Londres
# * "B42 1LG"   $ \rightarrow  $   Birmingham
# * "B28 9AD"   $ \rightarrow  $   British Radio
# * "W12 7RJ"   $ \rightarrow  $   London, centre de notícies de la BBC
# * "BBC 007"   $ \rightarrow  $   Un codi postal no vàlid

# %%
VALID_POSTAL: Final[str] = (
    "SW1A 0AASW1A 1AASW1A 2AABX3 2BBDH98 1BTN1 9GUE98 1TTEC2N 2DBSE9 2UG" + 
    "N1 0UYEC1V 8DSB42 1LGB28 9ADW12 7RJ"
)

def validar_codi_postal(codi):
    """Funció que comprova si un codi postal del Regne Unit és correcte.
    
    Paràmetres:
    -----------
    codi_postal : str
        El codi postal que cal comprovar.

    Retorna:
    --------
    str
        Missatge que indica si el codi postal és correcte o incorrecte.
    """

    if re.search(codi, VALID_POSTAL) == None:
        return codi + "no és un codi postal vàlid!"
    
    return codi + "és correcte"

# %% [markdown]
# Fes una altra funció que donant-li una llista de codis t'imprimeixi per pantalla si cadascun d'ells és un codi vàlid al Regne Unit o no, i et retorni un diccionari de codis on es pugui cercar si és un codi vàlid (True) o no vàlid (False).

# %%
def validar_molts_codis(codis_postals):
    """Comprova si els codis postals del Regne Unit d'una llista són valids.

    Paràmetres:
    -----------
    codis_postals : list[str]
        La llista de codis postals que cal comprovar.

    Retorna:
    --------
    dict[bool]
        Diccionari amb els codis postals de la llista on indica si cadascun
        d'ells és correcte o incorrecte.
    """
    d: dict[str, bool] = {}
    for codi in codis_postals:
            if re.search(codi, VALID_POSTAL) != None:
                d[codi] = True
            else:
                d[codi] = False
    
    return d

# %%
codis_dubtosos = [
        "SW1A 0AA", # House of Commons
        "SW1A 1AA", # Palau de Buckingham
        "SW1A 2AA", # Downing Street
        "BX3 2BB",  # Barclays Bank
        "DH98 1BT", # British Telecom
        "N1 9GU",   # Guardian Newspaper
        "E98 1TT",  # The Times
        "TIM E22",  # Codi postal fals
        "A B1 A22", # Codi postal no vàlid
        "EC2N 2DB", # Deutsche Bank
        "SE9 2UG",  # Universitat de Greenwhich
        "N1 0UY",   # Islington, Londres
        "EC1V 8DS", # Clerkenwell, Londres
        "B42 1LG",  # Birmingham
        "B28 9AD",  # British Radio 
        "W12 7RJ",  # Londres, BBC News Centre
        "BBC 007"   # Codi postal no vàlid
    ]
diccionari_codis_valids = {
        "SW1A 0AA": True, # House of Commons
        "SW1A 1AA": True, # Palau de Buckingham
        "SW1A 2AA": True, # Downing Street
        "BX3 2BB": True,  # Barclays Bank
        "DH98 1BT": True, # British Telecom
        "N1 9GU": True,   # Guardian Newspaper
        "E98 1TT": True,  # The Times
        "TIM E22": False,  # Codi postal fals
        "A B1 A22": False, # Codi postal no vàlid
        "EC2N 2DB": True, # Deutsche Bank
        "SE9 2UG": True,  # Universitat de Greenwhich
        "N1 0UY": True,   # Islington, Londres
        "EC1V 8DS": True, # Clerkenwell, Londres
        "B42 1LG": True,  # Birmingham
        "B28 9AD": True,  # British Radio 
        "W12 7RJ": True,  # Londres, BBC News Centre
        "BBC 007": False   # Codi postal no vàlid
} 
assert(validar_molts_codis(codis_dubtosos) == diccionari_codis_valids)
