# %% [markdown]
# # 📖 Tema 3 - Recursivitat

# %% [markdown]
# ### ✍️ Problema 5.1 Suma Llista

# %% [markdown]
# Escriu una **funció recursiva** `suma_llista(llista)` que calculi la **suma de tots els elements** d’una llista d’enters.
#
# ---
#
# #### 🧠 Tasques a realitzar
#
# 1. Implementa la funció `suma_llista(llista)` fent ús exclusiu de **recursivitat** (sense bucles `for` o `while`).
# 2. Identifica clarament quin és el **cas base** de l’algorisme.

# %%
def suma_llista(llista:list[int]):
    """
    Calcula de forma recursiva la suma de tots els elements d'una llista numèrica.

    Parameters
    ----------
    llista : list
        Llista d’elements numèrics (int o float).

    Returns
    -------
    int | float
        La suma total de tots els elements de la llista.
    """

    if len(llista) <= 1:
        if len(llista) == 1: return llista[0]
        else: return 0

    return(llista[0] + llista[-1] + suma_llista(llista[1:-1]))

# %% [markdown]
# ### 📊 Càlcul complexitat
#
# Repeteix el codi de la teva funció i detalla els passos computacionals i l'ordre de complexitat amb O gran.

# %% [markdown]
# La complexidad del recursive es O(n), y hay que hacer un slicing de O(n).
# Complexidad total es  O(n) * O(n) = O(n^2)
